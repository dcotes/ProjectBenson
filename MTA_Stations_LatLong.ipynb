# %%
# Setup necessary libraries

% pylab inline
# see https://ipython.readthedocs.io/en/stable/interactive/magics.html

% config InlineBackend.figure_format = 'svg'
import pandas as pd
import urllib
import json

print("Pandas version:", pd.__version__)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 125)
pd.set_option('display.precision', 3)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Pandas version: 0.23.4

# %%
# Read turnstile data
df2 = pd.read_csv(
    'http://web.mta.info/developers/data/nyct/turnstile/turnstile_180922.txt'
    )

# %%
# Set variables for the API
gmaps_base_url = 'https://maps.googleapis.com/maps/api/geocode/json?'
api_key = 'AIzaSyBrSMdjoUWrRflbtMYx3LDcXgzXR_puIF0'
scontext = None

# Create a list of station to source the search on Google API
mta_stations = list(df2['STATION'].unique())

# Create a dataframe to collect search results
locs = pd.DataFrame(data=None)

# %%
# Search through the list of station (mta_stations)
for station in mta_stations:
    try:
        search_criteria = {'address': station + 'Subway station, New York, NY',
                           'key' : api_key
                           }
        url = gmaps_base_url + urllib.parse.urlencode(search_criteria)
        uh = urllib.request.urlopen(url, context=scontext)
        data = uh.read()
        js = json.loads(data)
        lat = js['results'][0]['geometry']['location']['lat']
        long = js['results'][0]['geometry']['location']['lng']
        locs = locs.append(pd.Series((station, lat, long)), ignore_index=True)
    except:
        print(station)
# Out:
# AVENUE J

# %%
# # Fix errors
# errors = {'CONEY IS-STILLW' : ['40.7491675','-73.8694786']}

# # Append fixed records
# for station, lat, long in errors.iterrows():
#     locs = locs.append(pd.Series((station, lat, long)), ignore_index=True)

# %%
# Rename the columns in locs (output table)
locs.rename(columns={0: 'STATION',1: 'LATITUDE',2: 'LONGITUDE'}, inplace=True)

# %%
# Check the output table
locs
# Out:
#              STATION  LATITUDE  LONGITUDE
# 0              59 ST    40.763    -73.968
# 1         5 AV/59 ST    40.765    -73.973
# 2         57 ST-7 AV    40.766    -73.980
# 3              49 ST    40.760    -73.984
# 4     TIMES SQ-42 ST    40.755    -73.987
# 5    34 ST-HERALD SQ    40.749    -73.989
# 6              28 ST    40.743    -73.984
# 7              23 ST    40.746    -73.998
# 8     14 ST-UNION SQ    40.735    -73.991
# 9           8 ST-NYU    40.731    -73.993
# 10         PRINCE ST    40.724    -73.998
# 11          CANAL ST    40.720    -74.002
# 12         CITY HALL    40.713    -74.007
# 13      CORTLANDT ST    40.711    -74.011
# 14         RECTOR ST    40.708    -74.014
# 15   WHITEHALL S-FRY    40.702    -74.013
# 16    DELANCEY/ESSEX    40.719    -73.988
# 17            BOWERY    40.720    -73.994
# 18       CHAMBERS ST    40.716    -74.009
# 19         FULTON ST    40.709    -74.008
# 20          BROAD ST    40.707    -74.011
# 21              7 AV    40.762    -73.986
# 22        PARK PLACE    40.675    -73.958
# 23    BOTANIC GARDEN    40.671    -73.958
# 24     PROSPECT PARK    40.661    -73.962
# 25       PARKSIDE AV    40.655    -73.961
# 26         CHURCH AV    40.644    -73.980
# 27     BEVERLEY ROAD    40.644    -73.964
# 28      CORTELYOU RD    40.641    -73.964
# 29     NEWKIRK PLAZA    40.635    -73.963
# 30          AVENUE H    40.777    -73.952
# 31          AVENUE J    40.625    -73.961
# 32          AVENUE M    40.777    -73.952
# 33         KINGS HWY    40.609    -73.958
# 34          AVENUE U    40.777    -73.952
# 35           NECK RD    40.595    -73.955
# 36    SHEEPSHEAD BAY    40.587    -73.954
# 37    BRIGHTON BEACH    40.578    -73.961
# 38        OCEAN PKWY    40.576    -73.969
# 39      BOROUGH HALL    40.693    -73.990
# 40   JAY ST-METROTEC    40.692    -73.987
# 41         DEKALB AV    40.690    -73.981
# 42    ATL AV-BARCLAY    40.684    -73.979
# 43          UNION ST    40.677    -73.983
# 44          4AV-9 ST    40.670    -73.989
# 45       PROSPECT AV    40.701    -73.987
# 46             25 ST    40.660    -73.998
# 47             36 ST    40.655    -74.004
# 48             45 ST    40.649    -74.010
# 49             53 ST    40.760    -73.976
# 50      BAY RIDGE AV    40.635    -74.023
# 51             77 ST    40.774    -73.960
# 52             86 ST    40.777    -73.952
# 53   BAY RIDGE-95 ST    40.617    -74.031
# 54              8 AV    40.740    -74.003
# 55   FT HAMILTON PKY    40.651    -73.976
# 56    NEW UTRECHT AV    40.626    -73.997
# 57             18 AV    40.620    -73.989
# 58             20 AV    40.617    -73.985
# 59          BAY PKWY    40.612    -73.982
# 60              9 AV    40.646    -73.994
# 61             50 ST    40.762    -73.986
# ..               ...       ...        ...
# 312  E 143/ST MARY'S    40.808    -73.908
# 313         E 149 ST    40.818    -73.927
# 314      LONGWOOD AV    40.825    -73.892
# 315   HUNTS POINT AV    40.821    -73.891
# 316      WHITLOCK AV    40.827    -73.886
# 317         ELDER AV    40.826    -73.879
# 318  MORISN AV/SNDVW    40.829    -73.875
# 319   ST LAWRENCE AV    40.832    -73.867
# 320      PARKCHESTER    40.833    -73.861
# 321   CASTLE HILL AV    40.834    -73.852
# 322        ZEREGA AV    40.765    -73.973
# 323   WESTCHESTER SQ    40.840    -73.843
# 324    MIDDLETOWN RD    40.853    -73.826
# 325         BUHRE AV    40.847    -73.832
# 326  PELHAM BAY PARK    40.853    -73.827
# 327            5 AVE    40.765    -73.973
# 328   VERNON-JACKSON    40.743    -73.954
# 329    HUNTERS PT AV    40.742    -73.948
# 330   QUEENSBORO PLZ    40.749    -73.937
# 331            36 AV    40.757    -73.930
# 332            30 AV    40.767    -73.921
# 333     ASTORIA BLVD    40.767    -73.921
# 334  ASTORIA DITMARS    40.775    -73.912
# 335  33 ST-RAWSON ST    40.745    -73.931
# 336  40 ST LOWERY ST    40.744    -73.924
# 337   46 ST BLISS ST    40.743    -73.918
# 338            52 ST    40.744    -73.912
# 339   61 ST WOODSIDE    40.746    -73.903
# 340            69 ST    40.746    -73.896
# 341   74 ST-BROADWAY    40.747    -73.891
# 342  82 ST-JACKSON H    40.748    -73.884
# 343   90 ST-ELMHURST    40.749    -73.877
# 344    JUNCTION BLVD    40.749    -73.869
# 345    103 ST-CORONA    40.750    -73.863
# 346  METS-WILLETS PT    40.752    -73.844
# 347    FLUSHING-MAIN    40.760    -73.830
# 348  34 ST-HUDSON YD    40.755    -74.001
# 349         CLARK ST    40.697    -73.993
# 350          HOYT ST    40.691    -73.985
# 351        NEVINS ST    40.684    -73.984
# 352  GRAND ARMY PLAZ    40.675    -73.971
# 353  EASTN PKWY-MUSM    40.672    -73.964
# 354      KINGSTON AV    40.669    -73.942
# 355  CROWN HTS-UTICA    40.669    -73.932
# 356  SUTTER AV-RUTLD    40.665    -73.923
# 357      SARATOGA AV    40.765    -73.973
# 358        JUNIUS ST    40.663    -73.903
# 359  PENNSYLVANIA AV    40.665    -73.894
# 360      NEW LOTS AV    40.659    -73.899
# 361     PRESIDENT ST    40.668    -73.951
# 362      STERLING ST    40.663    -73.951
# 363      WINTHROP ST    40.714    -74.010
# 364       BEVERLY RD    40.644    -73.964
# 365       NEWKIRK AV    40.640    -73.948
# 366  FLATBUSH AV-B.C    40.661    -73.962
# 367      MORRIS PARK    40.855    -73.860
# 368    BAYCHESTER AV    40.879    -73.838
# 369  EASTCHSTER/DYRE    40.888    -73.831
# 370       ST. GEORGE    40.849    -73.934
# 371    TOMPKINSVILLE    40.638    -74.075
# 372    RIT-MANHATTAN    43.085    -77.674
# 373    RIT-ROOSEVELT    40.747    -73.891
#
# [374 rows x 3 columns]

# %%
# Export the output table
locs.to_csv('mtaLongLat.csv', sep='\t', encoding='utf-8')
